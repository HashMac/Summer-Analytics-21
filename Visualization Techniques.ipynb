# %% [markdown]
# # Matplotlib Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.plot([1,3,2,4])
plt.show()

# %%
plt.plot([1, 2, 3, 4],[1,4,9,16])
plt.title('Test Plot', fontsize = 8, color ='g' )
plt.xlabel('Number N')
plt.ylabel('N^2')
plt.show()

# %%
#Change figure size
plt.figure(figsize=(2,5))
plt.plot([1, 2, 3, 4],[1, 4, 9, 16],'rx')#Red-x
plt.axis([0, 6, 0, 20])#(0,6) on x-axis and (0,20) on y-axis
plt.annotate('Arrow',(3,6))
plt.show()

# %%
#Bar Charts with four bars
plt.clf() #Clear figure
x = np.arange(4) #Results in 0, 1, 2, 3 value
y = [8.8, 5.2, 3.6, 5.9]
plt.xticks(x,('Ankit','Hans','Joe','Flaco'))#Assigning names to x values
plt.bar(x,y)
#plt.bar(x,y, color = 'y')
#plt.bar(x, y, color = ['lime','r','k','tan'])
plt.show()

# %%
#2 sets of 20 random dots plotted
d = {'Red O':np.random.rand(10),
    'Grn X':np.random.rand(10)}
df = pd.DataFrame(d)
df.plot(style = ['ro','gx'])
plt.show()

# %%
#Time Series Analysis-6 months of random floats
ts = pd.Series(np.random.randn(180), index = pd.date_range('1/1/2018',periods = 180))
df = pd.DataFrame(np.random.randn(180,3), index = ts.index, columns = list('ABC'))
df.cumsum().plot()
plt.show()

# %%
#Random dots in Scatter
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
sizes = (30 * np.random.rand(N))**2 #0 to 15 radii of dots
plt.scatter(x,y, s=sizes, c = colors, alpha=0.5)#alpha: transparency level
plt.show()

# %%
df = pd.read_csv('Fremont_weather.txt')
print(df)
plt.bar(df['month'],df['record_high'], color='r')
plt.bar(df['month'], df['record_low'], color='c')
plt.plot(df['month'], df['avg_high'], color='k')
plt.plot(df['month'], df['avg_low'], color='b')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
#    month  avg_high  avg_low  record_high  record_low  avg_precipitation
# 0    Jan        58       42           74          22               2.95
# 1    Feb        61       45           78          26               3.02
# 2    Mar        65       48           84          25               2.34
# 3    Apr        67       50           92          28               1.02
# 4    May        71       53           98          35               0.48
# 5    Jun        75       56          107          41               0.11
# 6    Jul        77       58          105          44               0.00
# 7    Aug        77       59          102          43               0.03
# 8    Sep        77       57          103          40               0.17
# 9    Oct        73       54           96          34               0.81
# 10   Nov        64       48           84          30               1.70
# ...

# %%
#To plot sub-plots
fig = plt.figure()
fig.suptitle('My Subplots')
fig.add_subplot(221)
plt.plot([np.log(n) for n in range(1,10)])
fig.add_subplot(222, facecolor = 'y')
fig.add_subplot(223)#We can have more info to fill the graph
fig.add_subplot(224)
plt.show()

# %%
#Subplots=II
fig, plots = plt.subplots(2, sharex = True)
fig.suptitle('Sharing X axis')
x=range(0,200,5)
y = [n**0.8 for n in x]
plots[0].plot(x,y,color='r')
plots[1].scatter(x,y)
plt.show()

# %%
#Saving figure to img file
plt.figure(figsize = (4,3),dpi=100)
plt.plot([245, 170, 148, 239, 161, 196, 112, 258])
plt.axis([0, 7, 0, 300])
plt.title('Flight Data')
plt.xlabel('Speed')
plt.savefig('Flights.png')
plt.show()

# %% [markdown]
# # Seaborn Library

# %%
import seaborn as sns
from matplotlib import pyplot as plt
x = [10, 20, 30, 40]
y = [0, 15, 10, 25]
plt.plot(x,y)

# %%
#Better viz options available with .set()
sns.set()
plt.plot(x,y)

# %%
cars = sns.load_dataset('mpg')
type(cars)
cars.dropna(inplace=True)
cars.shape
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.relplot(x='model_year',y='mpg',col='origin',hue='cylinders',data=cars)

# %%
#Univariate KDE(Kernel Density Distribution)
from matplotlib import pyplot as plt
import seaborn as sns
cars = sns.load_dataset('mpg').dropna()
cars.shape
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.kdeplot(cars.horsepower)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
sns.kdeplot(cars.horsepower, shade = True)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
sns.kdeplot(cars.horsepower, bw_adjust = 3)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
sns.kdeplot(cars.horsepower, cumulative = True)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
#Bivariate KDE
sns.kdeplot(y = cars.mpg, x = cars.horsepower )
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
#To increase granuality
sns.kdeplot(y = cars.mpg, x = cars.horsepower, levels = 10)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
sns.kdeplot(x = cars.horsepower, y = cars.mpg, shade = True)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
sns.set_style('whitegrid')
sns.kdeplot(x = cars.horsepower, y = cars.mpg, 
            shade = True,
           levels = 10)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
sns.kdeplot(x = cars.horsepower, y = cars.mpg, 
            shade = True,
             levels = 10,
            cbar = True)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='mpg'>

# %%
from matplotlib import pyplot as plt
import seaborn as sns
cars = sns.load_dataset('mpg').dropna()
cars.shape
cars.head()
sns.set_style('white')

# %%
sns.distplot(x = cars.weight, rug = True)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(cars.weight, bins = 20)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %%
sns.distplot(cars.weight, bins = [1500, 2000, 2500, 3500, 5200])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %%
#Fit
from scipy.stats import norm
sns.distplot(cars.weight, fit=norm, kde = False)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight'>

# %%
#Fit
from scipy.stats import skewnorm
sns.distplot(cars.weight, fit=skewnorm, kde = False)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight'>

# %%
#Kwargs
sns.distplot(cars.weight, hist_kws = {'alpha':1,'histtype':'step'}, kde = False)
# Out:
# <AxesSubplot:xlabel='weight'>

# %%
sns.distplot(cars.weight, hist_kws = {'alpha':1,'histtype':'stepfilled'}, kde = False)
# Out:
# <AxesSubplot:xlabel='weight'>

# %%
#kde_kws
sns.distplot(cars.weight, kde_kws = {'lw':5})#length width
#Or
sns.distplot(cars.weight, lw=5)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-214-dac3727824cb> in <module>
#       2 sns.distplot(cars.weight, kde_kws = {'lw':5})#length width
#       3 #Or
# ----> 4 sns.distplot(cars.weight, lw=5)
#
# TypeError: distplot() got an unexpected keyword argument 'lw'

# %%
sns.distplot(cars.weight, kde_kws = {'bw' : 0.20})#bw: bandwidth
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:1659: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 0.2 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %%
#rug_kws
sns.distplot(cars.weight, rug = True, rug_kws = {'height':0.15})
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %%
sns.distplot(cars.weight, rug = True, 
             color = 'b',
             rug_kws = {'height':0.15, 'color':'xkcd:navy'})
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='weight', ylabel='Density'>

# %%
#Boxplot
from matplotlib import pyplot as plt
import seaborn as sns
cars = sns.load_dataset('mpg').dropna()
cars.shape
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.set_style('whitegrid')
cars.cylinders.value_counts()
# Out:
# 4    199
# 8    103
# 6     83
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
cars = cars[cars.cylinders.isin([4,6,8])]
sns.boxplot(cars.mpg)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='mpg'>

# %%
cars.mpg.describe()
# Out:
# count    385.000000
# mean      23.445455
# std        7.836911
# min        9.000000
# 25%       17.000000
# 50%       23.000000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %%
sns.boxplot(x=cars.origin, y=cars.mpg)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(x='origin',y='mpg',data=cars)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(x='origin',y='mpg',hue='cylinders', data =cars)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
cars.model_year.describe()
# Out:
# count    385.000000
# mean      75.961039
# std        3.692058
# min       70.000000
# 25%       73.000000
# 50%       76.000000
# 75%       79.000000
# max       82.000000
# Name: model_year, dtype: float64

# %%
cars['newer_model'] = cars.model_year > 76
sns.boxplot(x='origin', y ='mpg', hue = 'newer_model',data = cars)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(y='origin',x='mpg',
           data = cars)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(x='origin',y='mpg',
           data = cars,
           order = ['japan','usa','europe'])
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(x='origin',y='mpg',
           data = cars,
           order = ['japan','usa','europe'],
           hue_order = [True, False])
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(x='origin',y='mpg',
           data = cars,
           color = 'g')
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(x='origin',y='mpg',hue = 'newer_model',
           data = cars,
           order = ['japan','usa','europe'])
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(x='origin',y='mpg',hue = 'newer_model',
           data = cars,
           width = 0.5)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(x='origin',y='mpg',hue = 'newer_model',
           data = cars,
           linewidth = 2.5)#1.5 default
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(y='origin',x='mpg',hue = 'newer_model',
           data = cars,
           whis = 1)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
sns.boxplot(x='origin',y='mpg',hue = 'newer_model',
           data = cars,
           fliersize = 2)#To increase the diamond size
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %%
sns.boxplot(y='origin',x='mpg',hue = 'newer_model',
           data = cars,
           showcaps = False)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='origin'>

# %%
#Violinplot
from matplotlib import pyplot as plt
import seaborn as sns
cars = sns.load_dataset('mpg').dropna()
cars.shape
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.set_style('whitegrid')
cars.cylinders.value_counts()
# Out:
# 4    199
# 8    103
# 6     83
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
cars = cars[cars.cylinders.isin([4,6,8])]

# %%
sns.violinplot(cars.displacement)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='displacement'>

# %%
sns.violinplot(x=cars.cylinders, y=cars.displacement)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='displacement'>

# %%
sns.violinplot(x='cylinders', y ='displacement',
               hue = 'origin',
              data =cars)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='displacement'>

# %%
sns.violinplot(x='cylinders', y ='displacement',
               hue = 'origin',
              data =cars[cars.origin.isin(['japan','europe'])])
plt.legend(loc=2)

# %%
sns.violinplot(x='cylinders', y ='displacement',
               hue = 'origin',
              data =cars[cars.origin.isin(['japan','europe'])],
              split = True)
plt.legend(loc=2)

# %%
sns.violinplot(x='cylinders', y ='displacement',
               hue = 'origin',
              data =cars[cars.origin.isin(['japan','europe'])],
              split = True,
              inner = 'quartiles')
plt.legend(loc=2)

# %%
sns.violinplot(x='cylinders', y ='displacement',
               hue = 'origin',
              data =cars[cars.origin.isin(['japan','europe'])],
              split = True,
              scale = 'count')
plt.legend(loc=2)

# %%
sns.violinplot(x='cylinders', y ='displacement',
               hue = 'origin',
              data =cars[cars.origin.isin(['japan','europe'])],
              split = True,
              scale = 'count',
              scale_hue = False)
plt.legend(loc=2)

# %%
(
cars[cars.origin.isin(['japan','europe'])]
    .groupby('cylinders')
    .origin
    .value_counts()
)
# Out:
# cylinders  origin
# 4          japan     69
#            europe    61
# 6          japan      6
#            europe     4
# Name: origin, dtype: int64

# %%
sns.violinplot(x=cars.origin, y = cars.displacement,
              order = ['japan','europe','usa'])
# Out:
# <AxesSubplot:xlabel='origin', ylabel='displacement'>

# %%
sns.violinplot(x=cars.origin, y = cars.displacement,
              linewidth = 3)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='displacement'>

# %%
sns.violinplot(x=cars.origin, y = cars.displacement,
              bw = 0.3)#default 0.4
# Out:
# <AxesSubplot:xlabel='origin', ylabel='displacement'>

# %%
#Scatterplot (relational plot)
from matplotlib import pyplot as plt
import seaborn as sns
diamonds = sns.load_dataset('diamonds')
diamonds.shape
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds = diamonds[
    diamonds.cut.isin(['Premium','Good'])&
    diamonds.color.isin(['D','F','J'])].sample(n=100, random_state = 22)

diamonds.shape
# Out:
# (100, 10)

# %%
sns.set_style('whitegrid')
sns.scatterplot(diamonds.carat, diamonds.price)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x = 'carat', y = 'price', data = diamonds)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x = 'x', y = 'y', data=diamonds)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
#Semantic Variables

# %%
sns.scatterplot(x='carat', y='price', hue='cut',
               data = diamonds)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat', y='price', hue='cut',
               data = diamonds,
               palette = ['aqua', 'purple', 'blue', 'orange', 'brown'])
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat', y='price', hue='depth',
               data = diamonds)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat', y='price', style='cut',
                s = 100,
               data = diamonds)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat', y='price', size='cut',
               data = diamonds)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat', y='price', size='cut',
               data = diamonds,
               sizes = [50, 70, 90, 110, 130])
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat', y='price', size='depth',
               data = diamonds)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat', y='price', 
                hue='cut',
                style = 'cut',
                data = diamonds,
                s=100)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat', y='price', 
                hue='cut',
                style = 'color',
                data = diamonds,
                s=100)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat', y='price', 
                alpha = 0.5,
                data = diamonds,
                s=100)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(x='carat', y='price', 
                data = diamonds,
                s=100,
               marker='*',
               edgecolor='black')
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %%
#Seaborn Lineplot (Variation with time, trend, seasonality)
import seaborn as  sns
from matplotlib import pyplot as plt
import pandas as pd
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00482/dataset.zip
# Out:
# --2021-05-28 13:58:41--  https://archive.ics.uci.edu/ml/machine-learning-databases/00482/dataset.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 240539 (235K) [application/x-httpd-php]
# Saving to: 'dataset.zip'
#
#      0K .......... .......... .......... .......... .......... 21% 59.1K 3s
#     50K .......... .......... .......... .......... .......... 42% 40.7M 1s
#    100K .......... .......... .......... .......... .......... 63% 48.5M 0s
#    150K .......... .......... .......... .......... .......... 85% 46.1M 0s
#    200K .......... .......... .......... ....                 100%  134K=1.1s
#
# 2021-05-28 13:58:43 (212 KB/s) - 'dataset.zip' saved [240539/240539]

# %%
df = pd.read_csv('dataset.csv',parse_dates=[3])
df.head()
# Out:
#   SystemCodeNumber  Capacity  Occupancy         LastUpdated
# 0      BHMBCCMKT01       577         61 2016-10-04 07:59:42
# 1      BHMBCCMKT01       577         64 2016-10-04 08:25:42
# 2      BHMBCCMKT01       577         80 2016-10-04 08:59:42
# 3      BHMBCCMKT01       577        107 2016-10-04 09:32:46
# 4      BHMBCCMKT01       577        150 2016-10-04 09:59:48

# %%
df.rename(columns={'SystemCodeNumber':'Location','LastUpdated':'Timestamp'},inplace=True)
df['Day'] = df.Timestamp.dt.date
df['Month'] = df.Timestamp.dt.month
df['Hour'] = df.Timestamp.dt.hour

# %%
park = df[df.Location.isin(['Broad Street','NIA South'])]
park.head()
# Out:
#            Location  Capacity  Occupancy           Timestamp         Day  \
# 20171  Broad Street       690        178 2016-10-04 07:59:42  2016-10-04
# 20172  Broad Street       690        269 2016-10-04 08:25:42  2016-10-04
# 20173  Broad Street       690        415 2016-10-04 08:59:42  2016-10-04
# 20174  Broad Street       690        530 2016-10-04 09:32:46  2016-10-04
# 20175  Broad Street       690        600 2016-10-04 09:59:48  2016-10-04
#
#        Month  Hour
# 20171     10     7
# 20172     10     8
# 20173     10     8
# 20174     10     9
# 20175     10     9

# %%
blue, orange, green, red = sns.color_palette()[:4]

# %%
sns.set_style('dark')
plt.rc('xtick',labelsize=14)
plt.rc('ytick',labelsize=14)
plt.rc('date.autoformatter',day='%b %Y')

# %%
months = [pd.datetime(2016, 10, 1),pd.datetime(2016, 11, 1), pd.datetime(2016, 12, 1)]
# Out:
# <ipython-input-369-fe186bfaf4bf>:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   months = [pd.datetime(2016, 10, 1),pd.datetime(2016, 11, 1), pd.datetime(2016, 12, 1)]

# %%
plt.figure(figsize = (10,6))
sns.lineplot(x = 'Day', y = 'Occupancy', ci = None, data = park)
plt.xticks(months)
plt.yticks([])
plt.xlim(None, pd.datetime(2016, 12, 1))
plt.ylim(0, 570)
sns.despine(left=True)
plt.xlabel('')
plt.ylabel('')
plt.tight_layout()
# Out:
# <ipython-input-373-02e1a7660599>:5: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   plt.xlim(None, pd.datetime(2016, 12, 1))

# %%
plt.figure(figsize=(10,6))
sns.lineplot(park.Day, park.Occupancy)
plt.xticks(months)
plt.yticks([])
plt.xlim(None, pd.datetime(2016, 12, 1))
plt.ylim(0, 570)
sns.despine(left=True)
plt.xlabel('')
plt.ylabel('')
plt.tight_layout();
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <ipython-input-371-dfdcb17a12e7>:5: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   plt.xlim(None, pd.datetime(2016, 12, 1))

# %%
plt.figure(figsize=(10,6))
sns.lineplot(park.Day, park.Occupancy, hue=park.Location, palette=['gray', 'purple'])
plt.xticks(months)
plt.yticks([])
plt.xlim(None, pd.datetime(2016, 12, 1))
sns.despine(left=True)
plt.xlabel('')
plt.ylabel('')
plt.legend([], frameon=False)
plt.tight_layout();
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <ipython-input-374-cdeb7f740605>:5: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   plt.xlim(None, pd.datetime(2016, 12, 1))

# %%
sns.lineplot(park.Hour, park.Occupancy)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Hour', ylabel='Occupancy'>

# %%
sns.lineplot(x='Hour', y='Occupancy', data = park,
            n_boot = 200)#Default 1000
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='Occupancy'>

# %% [markdown]
# To turn off the bootstrapped confidence intervals, set ci=None to trigger early exit within Seaborn code. (A conditional checks for this case and completely bypasses the bootstrapping procedure if ci is set to None. This saves time if confidence intervals are not needed!)

# %%
sns.lineplot(x='Hour', y='Occupancy', data=park,
             ci=None
            );

# %%
sns.lineplot(x='Hour', y='Occupancy', data = park,
            estimator = 'std')#Default mean
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='Occupancy'>

# %%
sns.lineplot(x='Day', y='Occupancy', data=park, hue='Location')

plt.xticks(months);

# %%
sns.lineplot(x='Day',y='Occupancy',data=park,
            hue = 'Location',
            palette = ['gray','xkcd:brick red'])

plt.xticks(months);

# %%
#Style
sns.lineplot(x='Day', y='Occupancy', data=park, style='Location')
plt.xticks(months);

# %%
sns.lineplot(x='Day', y='Occupancy', data=park, 
             hue='Location',
             style='Location')
plt.xticks(months);

# %%
sns.lineplot(x='Hour',y='Occupancy', data=park,
             size = 'Location')
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='Occupancy'>

# %%
sns.lineplot(x='Hour', y='Occupancy', data=park,
            ci=None,
            size='Month')
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='Occupancy'>

# %%
#Most of matplotlib's line styling works within the Seaborn lineplot. (The main exception is that linestyle does not work.)
sns.lineplot(x='Day', y='Occupancy', data=park, ci=None, 
             lw=4,
             color='#aa00aa',
             alpha=0.5
            )

plt.xticks(months);

# %%
#Seaborn heatmap
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np
cars = sns.load_dataset('mpg')
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
cars.groupby('origin').cylinders.value_counts()
# Out:
# origin  cylinders
# europe  4             63
#         6              4
#         5              3
# japan   4             69
#         6              6
#         3              4
# usa     8            103
#         6             74
#         4             72
# Name: cylinders, dtype: int64

# %%
origin_cyl = 
(cars
.groupby('origin')
.cylinders
.value_counts()
.unstack()
.fillna(0)
)

# %%
sns.heatmap(origin_cyl)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='origin'>

# %%
test_array = np.array([[1,2],[3,4]])
sns.heatmap(test_array)
# Out:
# <AxesSubplot:>

# %%
#Transpose
origin_cyl.T
# Out:
# origin     europe  japan    usa
# cylinders
# 3             0.0    4.0    0.0
# 4            63.0   69.0   72.0
# 5             3.0    0.0    0.0
# 6             4.0    6.0   74.0
# 8             0.0    0.0  103.0

# %%
sns.heatmap(origin_cyl.T)
# Out:
# <AxesSubplot:xlabel='origin', ylabel='cylinders'>

# %%
#Correlation
cars.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# displacement     -0.543684   -0.370164
# horsepower       -0.689196   -0.416361
# weight           -0.417457   -0.306564
# acceleration      1.000000    0.288137
# model_year        0.288137    1.000000

# %%
sns.heatmap(cars.corr())
# Out:
# <AxesSubplot:>

# %%
#Color Palette
sns.heatmap(origin_cyl, cmap='Blues')
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='origin'>

# %%
sns.heatmap(cars.corr(),cmap='RdBu', center=0)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(cars.corr(),cmap='RdBu', vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %%
#Annotations
sns.heatmap(origin_cyl,cmap='Blues', annot=True)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='origin'>

# %%
#To turn off the scientific notations
sns.heatmap(origin_cyl,cmap='Blues', annot=True, fmt='.0f')
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='origin'>

# %%
sns.heatmap(origin_cyl,
            cmap='Blues', 
            annot=True, 
            fmt='.0f',
           annot_kws={
               'fontsize':16,
               'fontweight':'bold',
               'fontfamily':'serif'
           })
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='origin'>

# %%
#Advanced Styling
sns.heatmap(cars.corr(),cmap='RdBu',linewidth=1)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(cars.corr(),
            cmap='RdBu',
            linewidth=1,
           linecolor='Black')
# Out:
# <AxesSubplot:>

# %%
labels = ['MPG','Cylinders','Displacement','Horsepower',
          'Weight','Acceleration', 'Model Year']

# %%
sns.heatmap(cars.corr(),
            cmap='RdBu',
            xticklabels=labels,
           yticklabels=labels)
# Out:
# <AxesSubplot:>

# %%
#Square
sns.heatmap(cars.corr(),cmap='RdBu',linewidth=1,square=True)
# Out:
# <AxesSubplot:>

# %%
#Pairplot

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set_style('darkgrid')

# %%
sns.pairplot(tips)

# %%
sns.distplot(tips['size'],
            kde=False,
            hist_kws={'alpha':1})
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='size'>

# %%
#diag_kind
sns.pairplot(tips, diag_kind='kde')

# %%
sns.pairplot(tips, kind='reg')

# %%
g = sns.pairplot(tips)

# %%
type(g)
# Out:
# seaborn.axisgrid.PairGrid

# %%
g=sns.pairplot(tips)
g.map_upper(sns.kdeplot, nlevel=6,color='xkcd:wine red')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:1181: UserWarning: The following kwargs were not used by contour: 'nlevel'
#   cset = contour_func(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:1181: UserWarning: The following kwargs were not used by contour: 'nlevel'
#   cset = contour_func(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:1181: UserWarning: The following kwargs were not used by contour: 'nlevel'
#   cset = contour_func(

# %%
#Categorical Values
tips['weekend'] = tips.day.isin(['Sat','Sun'])
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  weeken  weekend
# 0       16.99  1.01  Female     No  Sun  Dinner     2    True     True
# 1       10.34  1.66    Male     No  Sun  Dinner     3    True     True
# 2       21.01  3.50    Male     No  Sun  Dinner     3    True     True
# 3       23.68  3.31    Male     No  Sun  Dinner     2    True     True
# 4       24.59  3.61  Female     No  Sun  Dinner     4    True     True

# %%
sns.pairplot(tips, hue='weekend')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(tips, hue='weekend', vars=['total_bill','tip'])

# %%
sns.pairplot(tips, 
             hue='weekend', 
             y_vars=['tip'],
             x_vars=['total_bill', 'size'],
             kind='reg', 
             height=4);

# %%
#Advanced Styling
del tips['weekend']

# %%
#Height, Aspect
from ipywidgets import interactive
def size_widget(height=2.5, aspect=1):
    sns.pairplot(tips, height=height, aspect=aspect)

# %%
interactive(size_widget, height=(1,3.5,0.5),aspect=(0.5,2,0.25))
# Out:
# interactive(children=(FloatSlider(value=2.5, description='height', max=3.5, min=1.0, step=0.5), FloatSlider(va…

# %%
sns.pairplot(tips, hue='day',palette='plasma')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
#diag_kws, plot_kws
sns.pairplot(tips, diag_kws={'color':'gray','alpha':0.6})
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
sns.pairplot(tips, 
             kind='reg',
             plot_kws={'ci':None,'color':'xkcd:salmon',
                      'scatter_kws':{'color':'gray'}
                      }
            )
# Out:
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:5: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
#Seaborn Barplot(Categorical Estimate plot)
penguins = sns.load_dataset('penguins')
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.set_style('darkgrid')

# %%
sns.barplot(x='species',y='body_mass_g', data=penguins)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
penguins.groupby('species').body_mass_g.mean()
# Out:
# species
# Adelie       3700.662252
# Chinstrap    3733.088235
# Gentoo       5076.016260
# Name: body_mass_g, dtype: float64

# %%
#Horizontal Barplot
sns.barplot(y='species',x='body_mass_g', data=penguins)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='species'>

# %%
sns.barplot(x='species',
            y='body_mass_g',
            ci=99,
            data=penguins)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
#Estimator
sns.barplot(x='species',
            y='body_mass_g', 
            data=penguins,
            estimator = np.std)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
penguins.groupby('species').body_mass_g.describe()
# Out:
#            count         mean         std     min     25%     50%     75%  \
# species
# Adelie     151.0  3700.662252  458.566126  2850.0  3350.0  3700.0  4000.0
# Chinstrap   68.0  3733.088235  384.335081  2700.0  3487.5  3700.0  3950.0
# Gentoo     123.0  5076.016260  504.116237  3950.0  4700.0  5000.0  5500.0
#
#               max
# species
# Adelie     4775.0
# Chinstrap  4800.0
# Gentoo     6300.0

# %%
sns.barplot(x='species',
            y='body_mass_g', 
            data=penguins,
            estimator = np.max)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(x='species',
            y='body_mass_g',
            hue='sex',
            data=penguins,
           )
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(x='species',
            y='body_mass_g', 
            hue='sex',
            data=penguins,
            order=['Gentoo','Chinstrap','Adelie'],
           hue_order=['Female','Male'])
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(x='species',
            y='body_mass_g', 
            data=penguins,
            color = 'c',
           errcolor = 'darkslateblue',
           errwidth=8)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(x='species',
            y='body_mass_g', 
            data=penguins,
            palette='hot')
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
sns.barplot(x='species',
            y='body_mass_g', 
            data=penguins,
            ci=None,
            color='aliceblue',
            edgecolor='mediumblue',
            lw=3)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
#Stacked Barplot
sns.barplot(x='species',
            y='body_mass_g', 
            data=penguins,
            estimator = np.std)
# Out:
# <AxesSubplot:xlabel='species', ylabel='body_mass_g'>

# %%
penguins_sample = penguins.dropna().groupby(['species', 'sex']).sample(3, random_state=10)

penguins_sample
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 82      Adelie  Torgersen            36.7           18.8              187.0
# 6       Adelie  Torgersen            38.9           17.8              181.0
# 58      Adelie     Biscoe            36.5           16.6              181.0
# 14      Adelie  Torgersen            34.6           21.1              198.0
# 127     Adelie  Torgersen            41.5           18.3              195.0
# 109     Adelie     Biscoe            43.2           19.0              197.0
# 176  Chinstrap      Dream            46.7           17.9              195.0
# 182  Chinstrap      Dream            40.9           16.6              187.0
# 193  Chinstrap      Dream            46.2           17.5              187.0
# 171  Chinstrap      Dream            49.2           18.2              195.0
# 203  Chinstrap      Dream            51.4           19.0              201.0
# ...

# %%
sns.barplot(x='species', y='body_mass_g',
            data=penguins_sample[penguins_sample.sex == 'Female'],
            color='tab:blue',
            order = ['Adelie', 'Chinstrap', 'Gentoo'],
            ci=None,
            estimator=np.sum,
            saturation=1
           )
sns.barplot(x='species', y='body_mass_g',
            data=penguins_sample[penguins_sample.sex == 'Male'],
            color='tab:cyan',
            order = ['Adelie', 'Chinstrap', 'Gentoo'],
            ci = None,
            estimator = np.sum,
            bottom=(
                penguins_sample[penguins_sample.sex == 'Female']
                .groupby('species')
                .body_mass_g
                .sum()),
            saturation=1
           )

plt.ylabel('Sum of body mass (g)');

# %%
sns.set_style('white')

# %%
(penguins_sample
    .groupby(['species', 'sex'])
    .body_mass_g
    .sum()
    .unstack()
).plot(kind='bar', stacked=True, color=['tab:blue', 'tab:cyan'], width=0.8)

plt.xticks(rotation=0)
plt.ylabel('Sum of body mass (g)');

# %%
#Countplot
diamonds = sns.load_dataset('diamonds')
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds = diamonds[diamonds.clarity.isin(['SI1','VS2'])]
diamonds.shape
# Out:
# (25323, 10)

# %%
sns.set_style('darkgrid')

# %%
sns.countplot(x='color',data=diamonds)
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>

# %%
diamonds.color.value_counts(sort=False)
# Out:
# D    3780
# E    4896
# F    4332
# G    4323
# H    3918
# I    2593
# J    1481
# Name: color, dtype: int64

# %%
#Horizontal Countplot
sns.countplot(y='color',data=diamonds)
# Out:
# <AxesSubplot:xlabel='count', ylabel='color'>

# %%
#Order
diamonds.color.value_counts().index
# Out:
# CategoricalIndex(['E', 'F', 'G', 'H', 'D', 'I', 'J'], categories=['D', 'E', 'F', 'G', 'H', 'I', 'J'], ordered=False, dtype='category')

# %%
sns.countplot(x='color',data=diamonds,
             order=diamonds.color.value_counts().index[::-1])
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>

# %%
sns.countplot(x='color',
              data=diamonds,
              hue = 'clarity',
              hue_order = ['SI1','VS2'])
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>

# %%
sns.countplot(x='color',
              data=diamonds,
              color='skyblue')
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>

# %%
sns.countplot(x='color',
              data=diamonds,
              palette='twilight')
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>

# %%
sns.countplot(x='color',
              data=diamonds,
              lw = 4,
              ec='black',
              hatch='*')
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>

# %% [markdown]
# ##  5 Types of Big Data Visualization Categories

# %% [markdown]
# ### Temporal

# %% [markdown]
# Data visualizations belong in the temporal category if they satisfy two conditions: that they are linear, and that they are one-dimensional. Temporal visualizations normally feature lines that either stand alone or overlap with each other, with a start and finish time.
#
# Examples of temporal data visualization include:
#
# Scatter plots
#
# Polar area diagrams
#
# Time series sequences
#
# Timelines
#
# Line graphs

# %% [markdown]
# ### Hierarchical

# %% [markdown]
# Data visualizations that belong in the hierarchical category are those that order groups within larger groups. Hierarchical visualizations are best suited if you’re looking to display clusters of information, especially if they flow from a single origin point.
#
# Examples of hierarchical data visualizations include:
#
# Tree diagrams
#
# Ring charts
#
# Sunburst diagrams

# %% [markdown]
# ### Network

# %% [markdown]
# Datasets connect deeply with other datasets. Network data visualizations show how they relate to one another within a network. In other words, demonstrating relationships between datasets without wordy explanations.
#
# Examples of network data visualizations include:
#
# Matrix charts
#
# Node-link diagrams
#
# Word clouds
#
# Alluvial diagrams

# %% [markdown]
# ### Multidimensional

# %% [markdown]
# Just like the name, multidimensional data visualizations have multiple dimensions. This means that there are always 2 or more variables in the mix to create a 3D data visualization. Because of the many concurrent layers and datasets, these types of visualizations tend to be the most vibrant or eye-catching visuals. Another plus? These visuals can break down a ton of data down to key takeaways.
#
# Examples of multidimensional data visualizations include:
#
# Scatter plots
#
# Pie charts
#
# Venn diagrams
#
# Stacked bar graphs
#
# Histograms

# %% [markdown]
# ### Geospatial

# %% [markdown]
# Geospatial or spatial data visualizations relate to real life physical locations, overlaying familiar maps with different data points. These types of data visualizations are commonly used to display sales or acquisitions over time, and can be most recognizable for their use in political campaigns or to display market penetration in multinational corporations.
#
# Examples of geospatial data visualizations include:
#
# Flow map
#
# Density map
#
# Cartogram
#
# Heat map

# %% [markdown]
# ## The 17 Most Common Graph Types

# %% [markdown]
# [Bar Chart](https://www.klipfolio.com/resources/articles/what-is-data-visualization#DataViz1)
#
# [Line Chart](https://www.klipfolio.com/resources/articles/what-is-data-visualization#DataViz2)
#
# [Scatterplot](https://www.klipfolio.com/resources/articles/what-is-data-visualization#DataViz3)
#
# [Sparkline](https://www.klipfolio.com/resources/articles/what-is-data-visualization#DataViz4)
#
# [Pie Chart](https://www.klipfolio.com/resources/articles/what-is-data-visualization#DataViz5)
#
# [Gauge](https://www.klipfolio.com/resources/articles/what-is-data-visualization#DataViz6)
#
# [Waterfall Chart](https://www.klipfolio.com/resources/articles/what-is-data-visualization#DataViz7)
#
# [Funnel Chart](https://www.klipfolio.com/resources/articles/what-is-data-visualization#DataViz8)
#
# [Heat Map](https://www.klipfolio.com/resources/articles/what-is-data-visualization#DataViz9)
#
# [Histogram](https://www.klipfolio.com/resources/articles/what-is-data-visualization#DataViz10)
#
# [Box Plot](https://www.klipfolio.com/resources/articles/what-is-data-visualization#DataViz11)
#
# [Maps](https://www.klipfolio.com/resources/articles/what-is-data-visualization#DataViz12)
#
# [Tables](https://www.klipfolio.com/resources/articles/what-is-data-visualization#DataViz13)
#
# [Indicators](https://www.klipfolio.com/resources/articles/what-is-data-visualization#DataViz14)
#
# [Area Chart](https://www.klipfolio.com/resources/articles/what-is-data-visualization#DataViz15)
#
# [Radar or Spider Chart](https://www.klipfolio.com/resources/articles/what-is-data-visualization#DataViz16)
#
# [Tree Map](https://www.klipfolio.com/resources/articles/what-is-data-visualization#DataViz17)

# %% [markdown]
# # Various sources of readings

# %% [markdown]
# [Data Visualization using Matplotlib](https://towardsdatascience.com/data-visualization-using-matplotlib-16f1aae5ce70)

# %% [markdown]
# [Visualization with Seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html)

# %% [markdown]
# [Seaborn Official](https://seaborn.pydata.org/index.html)
